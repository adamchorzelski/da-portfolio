# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../data/raw/CarPrice_Assignment.csv')

print("Biblioteki załadowane! Gotowy do analizy.")
df
# Out:
# Biblioteki załadowane! Gotowy do analizy.
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
print("\nBrakujące wartości:")
print(df.isnull().sum())
# Out:
# Brakujące wartości:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df['brand'] = df['CarName'].apply(lambda x: x.split(' ')[0])

# %%
print("\nUnikalne marki przed poprawką:")
print(df['brand'].unique())
# Out:
# Unikalne marki przed poprawką:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'maxda' 'mazda' 'buick' 'mercury' 'mitsubishi' 'Nissan' 'nissan'
#  'peugeot' 'plymouth' 'porsche' 'porcshce' 'renault' 'saab' 'subaru'
#  'toyota' 'toyouta' 'vokswagen' 'volkswagen' 'vw' 'volvo']

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(subset="car_ID").sum()
# Out:
# 0

# %%
df.head(5)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  fuelsystem  \
# 0  convertible        rwd          front       88.6  ...        mpfi
# 1  convertible        rwd          front       88.6  ...        mpfi
# 2    hatchback        rwd          front       94.5  ...        mpfi
# 3        sedan        fwd          front       99.8  ...        mpfi
# 4        sedan        4wd          front       99.4  ...        mpfi
#
#    boreratio  stroke  compressionratio horsepower peakrpm  citympg highwaympg  \
# ...

# %%
df["CarName"].head(5)
# Out:
# 0          alfa-romero giulia
# 1         alfa-romero stelvio
# 2    alfa-romero Quadrifoglio
# 3                 audi 100 ls
# 4                  audi 100ls
# Name: CarName, dtype: object

# %%
df["CarName"].str.split().head(5)
# Out:
# 0          [alfa-romero, giulia]
# 1         [alfa-romero, stelvio]
# 2    [alfa-romero, Quadrifoglio]
# 3                [audi, 100, ls]
# 4                  [audi, 100ls]
# Name: CarName, dtype: object

# %%
df["CarName"].str.split().str[0].head(5)
# Out:
# 0    alfa-romero
# 1    alfa-romero
# 2    alfa-romero
# 3           audi
# 4           audi
# Name: CarName, dtype: object

# %%
df["brand"] = df["CarName"].str.split().str[0].str.lower().str.strip()

# %%
df["brand"].head(10)
# Out:
# 0    alfa-romero
# 1    alfa-romero
# 2    alfa-romero
# 3           audi
# 4           audi
# 5           audi
# 6           audi
# 7           audi
# 8           audi
# 9           audi
# Name: brand, dtype: object

# %%
df["brand"].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
df["brand"].nunique()
# Out:
# 27

# %%
df["brand"].value_counts().head(20)
# Out:
# brand
# toyota         31
# nissan         18
# mazda          15
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# volkswagen      9
# bmw             8
# buick           8
# audi            7
# plymouth        7
# saab            6
# isuzu           4
# porsche         4
# alfa-romero     3
# jaguar          3
# chevrolet       3
# Name: count, dtype: int64

# %%
sus = ["maxda", "porcshce", "toyouta", "vokswagen", "vw"]
mask = df["brand"].isin(sus)
mask
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Name: brand, Length: 205, dtype: bool

# %%
df_filtered = df[mask] # pokaż mi tylko te wiersze, gdzie maska = True
df_filtered
# Out:
#      car_ID  symboling            CarName fueltype aspiration doornumber  \
# 50       51          1          maxda rx3      gas        std        two
# 51       52          1   maxda glc deluxe      gas        std        two
# 126     127          3  porcshce panamera      gas        std        two
# 181     182         -1     toyouta tercel      gas        std       four
# 182     183          2   vokswagen rabbit   diesel        std        two
# 189     190          3          vw dasher      gas        std        two
# 190     191          3          vw rabbit      gas        std        two
#
#          carbody drivewheel enginelocation  wheelbase  ...  fuelsystem  \
# 50     hatchback        fwd          front       93.1  ...        2bbl
# 51     hatchback        fwd          front       93.1  ...        2bbl
# 126      hardtop        rwd           rear       89.5  ...        mpfi
# 181        wagon        rwd          front      104.5  ...        mpfi
# ...

# %%
df[df["brand"].isin(sus)]
# Out:
#      car_ID  symboling            CarName fueltype aspiration doornumber  \
# 50       51          1          maxda rx3      gas        std        two
# 51       52          1   maxda glc deluxe      gas        std        two
# 126     127          3  porcshce panamera      gas        std        two
# 181     182         -1     toyouta tercel      gas        std       four
# 182     183          2   vokswagen rabbit   diesel        std        two
# 189     190          3          vw dasher      gas        std        two
# 190     191          3          vw rabbit      gas        std        two
#
#          carbody drivewheel enginelocation  wheelbase  ...  fuelsystem  \
# 50     hatchback        fwd          front       93.1  ...        2bbl
# 51     hatchback        fwd          front       93.1  ...        2bbl
# 126      hardtop        rwd           rear       89.5  ...        mpfi
# 181        wagon        rwd          front      104.5  ...        mpfi
# ...

# %%
df_filtered["brand"]
# Out:
# 50         maxda
# 51         maxda
# 126     porcshce
# 181      toyouta
# 182    vokswagen
# 189           vw
# 190           vw
# Name: brand, dtype: object

# %%
df_filtered["brand"].value_counts()
# Out:
# brand
# maxda        2
# vw           2
# porcshce     1
# toyouta      1
# vokswagen    1
# Name: count, dtype: int64

# %%
fix_map = {
    "maxda": "mazda",
    "toyouta": "toyota",
    "vokswagen": "volkswagen",
    "vw": "Volkswagen",
    "porcsche": "porsche",
}
df["brand"] = df["brand"].replace(fix_map)

# %%
df["brand"].nunique()
# Out:
# 24

# %%
df["brand"].value_counts().head(10)
# Out:
# brand
# toyota        32
# nissan        18
# mazda         17
# honda         13
# mitsubishi    13
# subaru        12
# peugeot       11
# volvo         11
# volkswagen    10
# dodge          9
# Name: count, dtype: int64

# %%
df["brand"] = df["brand"].str.strip().str.lower()

# %%
fix_map = {
    "maxda": "mazda",
    "toyouta": "toyota",
    "vokswagen": "volkswagen",
    "vw": "volkswagen",
    "porcsche": "porsche",
}
df["brand"] = df["brand"].replace(fix_map)

# %%
df["brand"].value_counts().loc[lambda s: s.index.str.contains("volks", case=False)]
# Out:
# brand
# volkswagen    12
# Name: count, dtype: int64

# %%
df["brand"].nunique()
# Out:
# 23

# %%
df["brand"].value_counts().head(10)
# Out:
# brand
# toyota        32
# nissan        18
# mazda         17
# mitsubishi    13
# honda         13
# volkswagen    12
# subaru        12
# peugeot       11
# volvo         11
# dodge          9
# Name: count, dtype: int64

# %%
df["brand"].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'porcshce', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df["brand"].unique("volkswagen")
#
# TypeError: Series.unique() takes 1 positional argument but 2 were given
